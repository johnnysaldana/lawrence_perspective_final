# %%
#################################################################################################################
#                                                                                                               #
#                                                                                                               #
#                                       Lawrence Perspective Data Report                                        #
#                                                                                                               #
#                                                                                                               #
#################################################################################################################

# %%
# import packages

import numpy as np
import pandas as pd

# %%
# loads the accountability surveys as dataframes which is like 'python excel'

dfacc2016 = pd.read_excel('datasets//accountability2016schools.xlsx')
dfacc2015 = pd.read_excel('datasets//accountability2015schools.xlsx')
dfacc2014 = pd.read_excel('datasets//accountability2014schools.xlsx')
dfacc2013 = pd.read_excel('datasets//accountability2013schools.xlsx')
dfacc2012 = pd.read_excel('datasets//accountability2012schools.xlsx')

# 2016-2017 is missing for gender populations so I'm using the enrollment by grade to fill in the student counts
dfpop2016= pd.read_excel('datasets//enrollmentbygrade2016.xlsx')

# loads the selected population surveys as dataframes
dfselectedpop2016 = pd.read_excel('datasets//selectedpopulations2016.xlsx')
dfselectedpop2015 = pd.read_excel('datasets//selectedpopulations2015.xlsx')
dfselectedpop2014 = pd.read_excel('datasets//selectedpopulations2014.xlsx')
dfselectedpop2013 = pd.read_excel('datasets//selectedpopulations2013.xlsx')
dfselectedpop2012 = pd.read_excel('datasets//selectedpopulations2012.xlsx')

# loads the school gender population surveys as dataframes (using this for the student counts)

dfpop2015= pd.read_excel('datasets//classsizebygenderpopulation2015.xlsx')
dfpop2014 = pd.read_excel('datasets//classsizebygenderpopulation2014.xlsx')
dfpop2013 = pd.read_excel('datasets//classsizebygenderpopulation2013.xlsx')
dfpop2012 = pd.read_excel('datasets//classsizebygenderpopulation2012.xlsx')

# %%
# adds the high needs columns from the selected populations survey to the pop dataframe
dfpop2016 = dfpop2016.merge(dfselectedpop2016, on='org_code')
dfpop2015 = dfpop2015.merge(dfselectedpop2015, on='org_code')
dfpop2014 = dfpop2014.merge(dfselectedpop2014, on='org_code')
dfpop2013 = dfpop2013.merge(dfselectedpop2013, on='org_code')
dfpop2012 = dfpop2012.merge(dfselectedpop2012, on='org_code')

# removes all rows where level is absent or marked insufficient data in the accountability surveys

dfacc2016 = dfacc2016[dfacc2016.level_2016 != 'Insufficient data']
dfacc2016 = dfacc2016[dfacc2016['level_2016'].notnull()]

dfacc2015 = dfacc2015[dfacc2015.level_2015 != 'Insufficient data']
dfacc2015 = dfacc2015[dfacc2015['level_2015'].notnull()]

dfacc2014 = dfacc2014[dfacc2014.level_2014 != 'Insufficient data']
dfacc2014 = dfacc2014[dfacc2014['level_2014'].notnull()]

dfacc2013 = dfacc2013[dfacc2013.level_2013 != 'Insufficient data']
dfacc2013 = dfacc2013[dfacc2013['level_2013'].notnull()]

dfacc2012 = dfacc2012[dfacc2012.level_2012 != 'Insufficient data']
dfacc2012 = dfacc2012[dfacc2012['level_2012'].notnull()]

# changes the levels which are strings ex. 'level 1' to ints ex. '1'

dfacc2016['level_2016'] = dfacc2016['level_2016'].apply(lambda x: [int(x) for x in x.split() if x.isdigit()][0])
dfacc2015['level_2015'] = dfacc2015['level_2015'].apply(lambda x: [int(x) for x in x.split() if x.isdigit()][0])
dfacc2014['level_2014'] = dfacc2014['level_2014'].apply(lambda x: [int(x) for x in x.split() if x.isdigit()][0])
dfacc2013['level_2013'] = dfacc2013['level_2013'].apply(lambda x: [int(x) for x in x.split() if x.isdigit()][0])
dfacc2012['level_2012'] = dfacc2012['level_2012'].apply(lambda x: [int(x) for x in x.split() if x.isdigit()][0])

# gets the district and school name seperate for each row

dfacc2016['district'] = dfacc2016['school'].apply(lambda x: x[: x.index(' -')+1])
dfacc2016['school'] = dfacc2016['school'].apply(lambda x:  x[x.index(' -') + 3:])
dfacc2015['district'] = dfacc2015['school'].apply(lambda x: x[: x.index(' -')+1])
dfacc2015['school'] = dfacc2015['school'].apply(lambda x:  x[x.index(' -') + 3:])
dfacc2014['district'] = dfacc2014['school'].apply(lambda x: x[: x.index(' -')+1])
dfacc2014['school'] = dfacc2014['school'].apply(lambda x:  x[x.index(' -') + 3:])
dfacc2013['district'] = dfacc2013['school'].apply(lambda x: x[: x.index(' -')+1])
dfacc2013['school'] = dfacc2013['school'].apply(lambda x:  x[x.index(' -') + 3:])
dfacc2012['district'] = dfacc2012['school'].apply(lambda x: x[: x.index(' -')+1])
dfacc2012['school'] = dfacc2012['school'].apply(lambda x:  x[x.index(' -') + 3:])

# sets a name for each dataframe

dfacc2016.name = 'dfacc2016'
dfacc2015.name = 'dfacc2015'
dfacc2014.name = 'dfacc2014'
dfacc2013.name = 'dfacc2013'
dfacc2012.name = 'dfacc2012'

dfpop2016.name = 'dfpop2016'
dfpop2015.name = 'dfpop2015'
dfpop2014.name = 'dfpop2014'
dfpop2013.name = 'dfpop2013'
dfpop2012.name = 'dfpop2012'

# %%
# gets the district and school name seperate for each row

dfpop2016['district'] = dfpop2016['school'].apply(lambda x: x[: x.index(' -')+1])
dfpop2016['school'] = dfpop2016['school'].apply(lambda x:  x[x.index(' -') + 3:])
dfpop2015['district'] = dfpop2015['school'].apply(lambda x: x[: x.index(' -')+1])
dfpop2015['school'] = dfpop2015['school'].apply(lambda x:  x[x.index(' -') + 3:])
dfpop2014['district'] = dfpop2014['school'].apply(lambda x: x[: x.index(' -')+1])
dfpop2014['school'] = dfpop2014['school'].apply(lambda x:  x[x.index(' -') + 3:])
dfpop2013['district'] = dfpop2013['school'].apply(lambda x: x[: x.index(' -')+1])
dfpop2013['school'] = dfpop2013['school'].apply(lambda x:  x[x.index(' -') + 3:])
dfpop2012['district'] = dfpop2012['school'].apply(lambda x: x[: x.index(' -')+1])
dfpop2012['school'] = dfpop2012['school'].apply(lambda x:  x[x.index(' -') + 3:])

# %%
## merges the school populations survey with the accountability survey

df2016schools = pd.merge(dfacc2016, dfpop2016,  how='left', left_on=['org_code','school', 'district'], right_on = ['org_code','school','district'])
df2015schools = pd.merge(dfacc2015, dfpop2015,  how='left', left_on=['org_code','school', 'district'], right_on = ['org_code','school','district'])
df2014schools = pd.merge(dfacc2014, dfpop2014,  how='left', left_on=['org_code','school', 'district'], right_on = ['org_code','school','district'])
df2013schools = pd.merge(dfacc2013, dfpop2013,  how='left', left_on=['org_code','school', 'district'], right_on = ['org_code','school','district'])
df2012schools = pd.merge(dfacc2012, dfpop2012,  how='left', left_on=['org_code','school', 'district'], right_on = ['org_code','school','district'])

# names the new dataframes
df2016schools.name = 'df2016schools'
df2015schools.name = 'df2015schools'
df2014schools.name = 'df2014schools'
df2013schools.name = 'df2013schools'
df2012schools.name = 'df2012schools'

len(df2016schools)
# Out:
# 1621

# %%
# creates a new dataframe that is district based rather than school based

# WARNING: come back to this. Some schools are being counted as zero so results are skewed
import math

def fix_none_type(x):
    if math.isnan(x):
        return 0
    else:
        return x
    
# this function takes in one of the school dataframes (ex. df2012) and then creates a district dataframe with lots of new columns
for i in range(2,7):
    exec('dforiginal = df201' + str(i) + 'schools')
    df = dforiginal 
    df.name = dforiginal.name
    # gets the list of districts for the dataframe
    district_lst = [] 
    for index, row in df.iterrows():
        if row['district'] not in district_lst:
            district_lst.append(row['district'])
            
    exec( (df.name)[:6] + 'district = pd.DataFrame(district_lst, columns=["district"]) ' )
    
    # gets the list of school numbers in each district for the dataframe
    lst_school_count = []
    school_count = 0
    current_district = df.iloc[0]['district']
    for index, row in df.iterrows():
        if index == len(df)-1:
            lst_school_count.append(school_count)
            
        elif row['district'] == current_district:
            school_count += 1
        else:
            current_district = row['district']
            lst_school_count.append(school_count)
            school_count = 1 
            
    exec( (df.name)[:6] + 'district["school count"] = lst_school_count ' ) 
    
    # gets the list of number of students in each district
    lst_student_count = []
    student_count = 0
    current_district = df.iloc[0]['district']
    for index, row in df.iterrows():
        if index == len(df)-1:
            lst_student_count.append(student_count)
            
        elif row['district'] == current_district:
            student_count += fix_none_type( row['student_count'] )
        else:
            current_district = row['district']
            lst_student_count.append(student_count)
            student_count = fix_none_type(row['student_count'] )
    exec( (df.name)[:6] + 'district["student count"] = lst_student_count ' )  
    
    # gets the list of number of students under level 3
    lst_students_under3 = []
    under3_count = 0
    current_district = df.iloc[0]['district']
    for index, row in df.iterrows():
        if index == len(df)-1:
            lst_students_under3.append(under3_count)
            
        elif row['district'] == current_district:
            if row['level_201'+ str(i)] >= 3:
                under3_count += fix_none_type(row['student_count'] )
        else:
            current_district = row['district']
            lst_students_under3.append(under3_count)
            if row['level_201'+ str(i)] >= 3:
                under3_count = fix_none_type(row['student_count'] ) 
            else:
                under3_count = 0

    exec( (df.name)[:6] + 'district["students under 3"] = lst_students_under3 ' ) 
    
    # creates column with percentage of students that are under level 3    
    under3_prcnt_lst = []
    exec( 'iterrtemp = '+(df.name)[:6] + 'district.iterrows()' )
    for index, row in iterrtemp:
        if row['student count'] == 0:
            under3_prcnt_lst.append(0)
            
        else:
            under3_prcnt_lst.append(fix_none_type(row['students under 3']) / row['student count'])
            
    exec( (df.name)[:6] + 'district["students under 3 %"] = under3_prcnt_lst' ) 
            
    # gets the list of number of high need students in the district
    lst_high_needs = []
    high_needs_count = 0
    current_district = df.iloc[0]['district']
    for index, row in df.iterrows():
        if index == len(df)-1:
            lst_high_needs.append(high_needs_count)
            
        elif row['district'] == current_district:
            high_needs_count += fix_none_type(row['high_needs_nmbr'])
        else:
            current_district = row['district']
            lst_high_needs.append(high_needs_count)
            high_needs_count = fix_none_type(row['high_needs_nmbr'] )
            

    exec( (df.name)[:6] + 'district["high needs count"] = lst_high_needs ' ) 
    
    # creates column with percentage of students that are high needs  
    high_needs_percent = []
    exec( 'iterrtemp = '+(df.name)[:6] + 'district.iterrows()' )
    for index, row in iterrtemp:
        if row['student count'] == 0:
            high_needs_percent.append(0)
        else:
            high_needs_percent.append(fix_none_type(row['high needs count']) / row['student count'])
            
    exec( (df.name)[:6] + 'district["high needs %"] = high_needs_percent' )

# %%
df2016district
# Out:
#                                               district  school count  \
# 0        Abby Kelley Foster Charter Public (District)              1
# 1                                            Abington              4
# 2    Academy Of the Pacific Rim Charter Public (Dis...             1
# 3                                    Acton-Boxborough              8
# 4                                            Acushnet              2
# 5                                      Adams-Cheshire              3
# 6    Advanced Math and Science Academy Charter (Dis...             1
# 7                                              Agawam              7
# 8                                            Amesbury              4
# 9                                             Amherst              3
# 10                                     Amherst-Pelham              2
# 11                                            Andover              9
# 12                                          Arlington              9
# ...

# %%
# new dataframe that uses percentage and removes districts with 4 or less schools

n = 9000

df2016district = df2016district[df2016district['student count'] > n]
df2015district = df2015district[df2015district['student count'] > n]
df2014district = df2014district[df2014district['student count'] > n]
df2013district = df2013district[df2013district['student count'] > n]
df2012district = df2012district[df2012district['student count'] > n]

w = 0.69

df2016district = df2016district[df2016district['high needs %'] > .6]
df2015district = df2015district[df2015district['high needs %'] > .6]
df2014district = df2014district[df2014district['high needs %'] > .6]
df2013district = df2013district[df2013district['high needs %'] > .62]
df2012district = df2012district[df2012district['high needs %'] > .6]


len(df2015district)
df2014district
# Out:
#          district  school count  student count  students under 3  \
# 41        Boston            102        47122.0           29651.0
# 57      Brockton             18        16142.0           11205.0
# 110   Fall River             13         9429.0            5064.0
# 167     Lawrence             26        12531.0            8735.0
# 179       Lowell             21        13857.0            7912.0
# 183         Lynn             23        14189.0            8297.0
# 230  New Bedford             23        12530.0            9537.0
# 324  Springfield             42        17645.0           15140.0
# 381    Worcester             44        26533.0           16456.0
#
#      students under 3 %  high needs count  high needs %
# 41             0.629239           33469.0      0.710263
# 57             0.694152           10087.0      0.624892
# 110            0.537066            6236.0      0.661364
# 167            0.697071            9808.0      0.782699
# ...

# %%
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt


dfplot1 = df2012district.sort_values(['high needs %'] , ascending=False)

N1 = len(dfplot1)

width = 0.4       # the width of the bars
 

x1 = []
for index, row in dfplot1.iterrows():
    x1.append( (row['students under 3 %']) )

ind = np.arange(N1)
fig, ax = plt.subplots()

rects1 = ax.bar(ind, x1, width, color='b', alpha=0.4)
rects1[0].set_color('red')

# add some text for labels, title and axes ticks
ax.set_ylabel('% Students Level 3 or Higher')
ax.set_xlabel('District')
ax.set_title('Percentage of Students Level 3 or Higher 2012 (Sorted by % High Needs Students in District Descending)')
ax.set_xticks(ind + width / len(dfplot1) )
ax.set_xticklabels(dfplot1['district'])

plt.setp(ax.get_xticklabels(), rotation=35, horizontalalignment='right')
        

plt.ylim([.35,1])


plt.savefig('percentage_Students_lvl3orhigher_2012.png', dpi=600, bbox_inches='tight')


plt.show()

# %%
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt


dfplot1 = df2013district.sort_values(['high needs %'] , ascending=False)

N1 = len(dfplot1)

width = 0.35       # the width of the bars
 

x1 = []
for index, row in dfplot1.iterrows():
    x1.append( (row['students under 3 %']) )

ind = np.arange(N1)
fig, ax = plt.subplots()

rects1 = ax.bar(ind, x1, width, color='b', alpha=0.4)
rects1[0].set_color('red')

# add some text for labels, title and axes ticks
ax.set_ylabel('% Students Level 3 or Higher')
ax.set_xlabel('District')
ax.set_title('Percentage of Students Level 3 or Higher 2013 (Sorted by % High Needs Students in District Descending)')
ax.set_xticks(ind + width / len(dfplot1) )
ax.set_xticklabels(dfplot1['district'])

plt.setp(ax.get_xticklabels(), rotation=35, horizontalalignment='right')
        

plt.ylim([.35,1])


plt.savefig('percentage_Students_lvl3orhigher_2013.png', dpi=600, bbox_inches='tight')


plt.show()

# %%
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt


dfplot1 = df2014district.sort_values(['high needs %'] , ascending=False)

N1 = len(dfplot1)

width = 0.35       # the width of the bars
 

x1 = []
for index, row in dfplot1.iterrows():
    x1.append( (row['students under 3 %']) )

ind = np.arange(N1)
fig, ax = plt.subplots()

rects1 = ax.bar(ind, x1, width, color='b', alpha=0.4)
rects1[0].set_color('red')

# add some text for labels, title and axes ticks
ax.set_ylabel('% Students Level 3 or Higher')
ax.set_xlabel('District')
ax.set_title('Percentage of Students Level 3 or Higher 2014 (Sorted by % High Needs Students in District Descending)')
ax.set_xticks(ind + width / len(dfplot1) )
ax.set_xticklabels(dfplot1['district'])

plt.setp(ax.get_xticklabels(), rotation=35, horizontalalignment='right')
        

plt.ylim([.35,1])


plt.savefig('percentage_Students_lvl3orhigher_2014.png', dpi=600, bbox_inches='tight')


plt.show()

# %%
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt


dfplot1 = df2015district.sort_values(['high needs %'] , ascending=False)

N1 = len(dfplot1)

width = 0.35       # the width of the bars
 

x1 = []
for index, row in dfplot1.iterrows():
    x1.append( (row['students under 3 %']) )

ind = np.arange(N1)
fig, ax = plt.subplots()

rects1 = ax.bar(ind, x1, width, color='b', alpha=0.4)
rects1[1].set_color('red')

# add some text for labels, title and axes ticks
ax.set_ylabel('% Students Level 3 or Higher')
ax.set_xlabel('District')
ax.set_title('Percentage of Students Level 3 or Higher 2015 (Sorted by % High Needs Students in District Descending)')
ax.set_xticks(ind + width / len(dfplot1) )
ax.set_xticklabels(dfplot1['district'])

plt.setp(ax.get_xticklabels(), rotation=35, horizontalalignment='right')
        

plt.ylim([.35,1])


plt.savefig('percentage_Students_lvl3orhigher_2015.png', dpi=600, bbox_inches='tight')


plt.show()

# %%
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt


dfplot1 = df2016district.sort_values(['high needs %'] , ascending=False)

N1 = len(dfplot1)

width = 0.35       # the width of the bars
 

x1 = []
for index, row in dfplot1.iterrows():
    x1.append( (row['students under 3 %']) )

ind = np.arange(N1)
fig, ax = plt.subplots()

rects1 = ax.bar(ind, x1, width, color='b', alpha=0.4)
rects1[0].set_color('red')

# add some text for labels, title and axes ticks
ax.set_ylabel('% Students Level 3 or Higher')
ax.set_xlabel('District')
ax.set_title('Percentage of Students Level 3 or Higher 2016 (Sorted by % High Needs Students in District Descending)')
ax.set_xticks(ind + width / len(dfplot1) )
ax.set_xticklabels(dfplot1['district'])

plt.setp(ax.get_xticklabels(), rotation=35, horizontalalignment='right')
        

plt.ylim([.35,1])


plt.savefig('percentage_Students_lvl3orhigher_2016.png', dpi=600, bbox_inches='tight')


plt.show()

# %%
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt


dfplot1 = df2012district.sort_values(['high needs %'] , ascending=False)

N1 = len(dfplot1)

x1 = []
for index, row in dfplot1.iterrows():
    x1.append( (row['high needs %']) )
    
y1 = []
for index, row in dfplot1.iterrows():
    y1.append( (row['students under 3 %']) )
    
xline = np.array(x1)
yline = np.array(y1)

l = []
for index, row in dfplot1.iterrows():
    l.append( (row['district']) )
    
area = []
for index, row in dfplot1.iterrows():
    area.append( (row['student count']) * 0.01 )

    
labels = []
for index, row in dfplot1.iterrows():
    labels.append( row['district'] )
    
colors = ['r','b','b','b','b','b','b','b','b','b']

# add some text for labels, title and axes ticks
plt.title('% High Needs Students vs. % Students in level 3 or higher 2012')
plt.xlabel('% Students that are High Needs in District Descending', fontsize=12)
plt.ylabel('% students in level 3 or higher schools', fontsize=12)

plt.subplots_adjust(bottom = 0.1)
plt.scatter(
    x1,y1, marker='o', c=colors, s=area, alpha=0.5,
    cmap=plt.get_cmap('Spectral'))

for label, x1, y1 in zip(labels, x1, y1):
    plt.annotate(
        label,
        xy=(x1, y1), xytext=(5, -15),
        textcoords='offset points', ha='right', va='bottom',
        bbox=dict(boxstyle='round,pad=0.1', fc='white', alpha=0.0))

plt.xlim(.61, .92)
plt.ylim(.4, .93)

model = np.polyfit(xline, yline, 1)
predicted = np.polyval(model, [0,1])

plt.plot([0,1], predicted, lw=2)

plt.savefig('scatter_highneeds_vs_prcntunder3_2012.png', dpi=600, bbox_inches='tight')


plt.show()

# %%
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt


dfplot1 = df2013district.sort_values(['high needs %'] , ascending=False)

N1 = len(dfplot1)

x1 = []
for index, row in dfplot1.iterrows():
    x1.append( (row['high needs %']) )
    
y1 = []
for index, row in dfplot1.iterrows():
    y1.append( (row['students under 3 %']) )
    
xline = np.array(x1)
yline = np.array(y1)

l = []
for index, row in dfplot1.iterrows():
    l.append( (row['district']) )
    
area = []
for index, row in dfplot1.iterrows():
    area.append( (row['student count']) * 0.01 )

    
labels = []
for index, row in dfplot1.iterrows():
    labels.append( row['district'] )
    
colors = ['r','b','b','b','b','b','b','b','b','b']

# add some text for labels, title and axes ticks
plt.title('% High Needs Students vs. % Students in level 3 or higher 2013')
plt.xlabel('% Students that are High Needs in District Descending', fontsize=12)
plt.ylabel('% students in level 3 or higher schools', fontsize=12)

plt.subplots_adjust(bottom = 0.1)
plt.scatter(
    x1,y1, marker='o', c=colors, s=area, alpha=0.5,
    cmap=plt.get_cmap('Spectral'))

for label, x1, y1 in zip(labels, x1, y1):
    plt.annotate(
        label,
        xy=(x1, y1), xytext=(5, -15),
        textcoords='offset points', ha='right', va='bottom',
        bbox=dict(boxstyle='round,pad=0.1', fc='white', alpha=0.0))

plt.xlim(.61, .92)
plt.ylim(.4, .92)

model = np.polyfit(xline, yline, 1)
predicted = np.polyval(model, [0,1])

plt.plot([0,1], predicted, lw=2)

plt.savefig('scatter_highneeds_vs_prcntunder3_2013.png', dpi=600, bbox_inches='tight')


plt.show()

# %%
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt


dfplot1 = df2014district.sort_values(['high needs %'] , ascending=False)

N1 = len(dfplot1)

x1 = []
for index, row in dfplot1.iterrows():
    x1.append( (row['high needs %']) )
    
y1 = []
for index, row in dfplot1.iterrows():
    y1.append( (row['students under 3 %']) )
    
xline = np.array(x1)
yline = np.array(y1)

l = []
for index, row in dfplot1.iterrows():
    l.append( (row['district']) )
    
area = []
for index, row in dfplot1.iterrows():
    area.append( (row['student count']) * 0.01 )

    
labels = []
for index, row in dfplot1.iterrows():
    labels.append( row['district'] )
    
colors = ['r','b','b','b','b','b','b','b','b','b']

# add some text for labels, title and axes ticks
plt.title('% High Needs Students vs. % Students in level 3 or higher 2014')
plt.xlabel('% Students that are High Needs in District Descending', fontsize=12)
plt.ylabel('% students in level 3 or higher schools', fontsize=12)

plt.subplots_adjust(bottom = 0.1)
plt.scatter(
    x1,y1, marker='o', c=colors, s=area, alpha=0.5,
    cmap=plt.get_cmap('Spectral'))

for label, x1, y1 in zip(labels, x1, y1):
    plt.annotate(
        label,
        xy=(x1, y1), xytext=(5, -11),
        textcoords='offset points', ha='right', va='bottom',
        bbox=dict(boxstyle='round,pad=0.1', fc='white', alpha=0.0))

plt.xlim(.61, .92)
plt.ylim(.4, .92)

model = np.polyfit(xline, yline, 1)
predicted = np.polyval(model, [0,1])

plt.plot([0,1], predicted, lw=2)

plt.savefig('scatter_highneeds_vs_prcntunder3_2014.png', dpi=600, bbox_inches='tight')


plt.show()

# %%
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt


dfplot1 = df2015district.sort_values(['high needs %'] , ascending=False)

N1 = len(dfplot1)

x1 = []
for index, row in dfplot1.iterrows():
    x1.append( (row['high needs %']) )
    
y1 = []
for index, row in dfplot1.iterrows():
    y1.append( (row['students under 3 %']) )
    
xline = np.array(x1)
yline = np.array(y1)

l = []
for index, row in dfplot1.iterrows():
    l.append( (row['district']) )
    
area = []
for index, row in dfplot1.iterrows():
    area.append( (row['student count']) * 0.01 )

    
labels = []
for index, row in dfplot1.iterrows():
    labels.append( row['district'] )
    
colors = ['b','r','b','b','b','b','b','b','b','b']

# add some text for labels, title and axes ticks
plt.title('% High Needs Students vs. % Students in level 3 or higher 2015')
plt.xlabel('% Students that are High Needs in District Descending', fontsize=12)
plt.ylabel('% students in level 3 or higher schools', fontsize=12)

plt.subplots_adjust(bottom = 0.1)
plt.scatter(
    x1,y1, marker='o', c=colors, s=area, alpha=0.5,
    cmap=plt.get_cmap('Spectral'))

for label, x1, y1 in zip(labels, x1, y1):
    plt.annotate(
        label,
        xy=(x1, y1), xytext=(5, -15),
        textcoords='offset points', ha='right', va='bottom',
        bbox=dict(boxstyle='round,pad=0.1', fc='white', alpha=0.0))

plt.xlim(.61, .92)
plt.ylim(.4, .92)

model = np.polyfit(xline, yline, 1)
predicted = np.polyval(model, [0,1])

plt.plot([0,1], predicted, lw=2)

plt.savefig('scatter_highneeds_vs_prcntunder3_2015.png', dpi=600, bbox_inches='tight')


plt.show()

# %%
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt


dfplot1 = df2016district.sort_values(['high needs %'] , ascending=False)

N1 = len(dfplot1)

x1 = []
for index, row in dfplot1.iterrows():
    x1.append( (row['high needs %']) )
    
y1 = []
for index, row in dfplot1.iterrows():
    y1.append( (row['students under 3 %']) )
    
xline = np.array(x1)
yline = np.array(y1)

l = []
for index, row in dfplot1.iterrows():
    l.append( (row['district']) )
    
area = []
for index, row in dfplot1.iterrows():
    area.append( (row['student count']) * 0.01 )

    
labels = []
for index, row in dfplot1.iterrows():
    labels.append( row['district'] )
    
colors = ['r','b','b','b','b','b','b','b','b','b']

# add some text for labels, title and axes ticks
plt.title('% High Needs Students vs. % Students in level 3 or higher 2016')
plt.xlabel('% Students that are High Needs in District Descending', fontsize=12)
plt.ylabel('% students in level 3 or higher schools', fontsize=12)

plt.subplots_adjust(bottom = 0.1)
plt.scatter(
    x1,y1, marker='o', c=colors, s=area, alpha=0.5,
    cmap=plt.get_cmap('Spectral'))

for label, x1, y1 in zip(labels, x1, y1):
    plt.annotate(
        label,
        xy=(x1, y1), xytext=(5, -17),
        textcoords='offset points', ha='right', va='bottom',fontsize=9,
        bbox=dict(boxstyle='round,pad=.1', fc='white', alpha=0.0))

plt.xlim(.61, .92)
plt.ylim(.36, .92)

model = np.polyfit(xline, yline, 1)
predicted = np.polyval(model, [0,1])

plt.plot([0,1], predicted, lw=2)

plt.savefig('scatter_highneeds_vs_prcntunder3_2016.png', dpi=600, bbox_inches='tight')


plt.show()

# %%
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt


dfplot1 = df2012district.sort_values(['high needs %'] , ascending=False)

N1 = len(dfplot1)

width = 0.35       # the width of the bars
 

x1 = []
for index, row in dfplot1.iterrows():
    x1.append( (row['students under 3 %']) / (row['high needs %']) )

ind = np.arange(N1)
fig, ax = plt.subplots()

rects1 = ax.bar(ind, x1, width, color='b', alpha=0.4)
rects1[0].set_color('red')

# add some text for labels, title and axes ticks
ax.set_ylabel('Score (% Students lvl 3 or higher / % Students High Need)')
ax.set_xlabel('District')
ax.set_title('District Weighted Scores 2012 (Lower is Better)')
ax.set_xticks(ind + width / len(dfplot1) )
ax.set_xticklabels(dfplot1['district'])

plt.setp(ax.get_xticklabels(), rotation=35, horizontalalignment='right')
        

plt.ylim([.35,1.2])


plt.savefig('student_3orabove_div_highneeds_2012.png', dpi=600, bbox_inches='tight')


plt.show()

# %%
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt


dfplot1 = df2013district.sort_values(['high needs %'] , ascending=False)

N1 = len(dfplot1)

width = 0.35       # the width of the bars
 

x1 = []
for index, row in dfplot1.iterrows():
    x1.append( (row['students under 3 %']) / (row['high needs %']) )

ind = np.arange(N1)
fig, ax = plt.subplots()

rects1 = ax.bar(ind, x1, width, color='b', alpha=0.4)
rects1[0].set_color('red')

# add some text for labels, title and axes ticks
ax.set_ylabel('Score (% Students lvl 3 or higher / % Students High Need)')
ax.set_xlabel('District')
ax.set_title('District Weighted Scores 2013 (Lower is Better)')
ax.set_xticks(ind + width / len(dfplot1) )
ax.set_xticklabels(dfplot1['district'])

plt.setp(ax.get_xticklabels(), rotation=35, horizontalalignment='right')
        

plt.ylim([.35,1.2])


plt.savefig('student_3orabove_div_highneeds_2013.png', dpi=600, bbox_inches='tight')


plt.show()

# %%
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt


dfplot1 = df2014district.sort_values(['high needs %'] , ascending=False)

N1 = len(dfplot1)

width = 0.35       # the width of the bars
 

x1 = []
for index, row in dfplot1.iterrows():
    x1.append( (row['students under 3 %']) / (row['high needs %']) )

ind = np.arange(N1)
fig, ax = plt.subplots()

rects1 = ax.bar(ind, x1, width, color='b', alpha=0.4)
rects1[0].set_color('red')

# add some text for labels, title and axes ticks
ax.set_ylabel('Score (% Students lvl 3 or higher / % Students High Need)')
ax.set_xlabel('District')
ax.set_title('District Weighted Scores 2014 (Lower is Better)')
ax.set_xticks(ind + width / len(dfplot1) )
ax.set_xticklabels(dfplot1['district'])

plt.setp(ax.get_xticklabels(), rotation=35, horizontalalignment='right')
        

plt.ylim([.35,1.2])


plt.savefig('student_3orabove_div_highneeds_2014.png', dpi=600, bbox_inches='tight')


plt.show()

# %%
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt


dfplot1 = df2015district.sort_values(['high needs %'] , ascending=False)

N1 = len(dfplot1)

width = 0.35       # the width of the bars
 

x1 = []
for index, row in dfplot1.iterrows():
    x1.append( (row['students under 3 %']) / (row['high needs %']) )

ind = np.arange(N1)
fig, ax = plt.subplots()

rects1 = ax.bar(ind, x1, width, color='b', alpha=0.4)
rects1[1].set_color('red')

# add some text for labels, title and axes ticks
ax.set_ylabel('Score (% Students lvl 3 or higher / % Students High Need)')
ax.set_xlabel('District')
ax.set_title('District Weighted Scores 2015 (Lower is Better)')
ax.set_xticks(ind + width / len(dfplot1) )
ax.set_xticklabels(dfplot1['district'])

plt.setp(ax.get_xticklabels(), rotation=35, horizontalalignment='right')
        

plt.ylim([.35,1.2])


plt.savefig('student_3orabove_div_highneeds_2015.png', dpi=600, bbox_inches='tight')


plt.show()

# %%
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt


dfplot1 = df2016district.sort_values(['high needs %'] , ascending=False)

N1 = len(dfplot1)

width = 0.35       # the width of the bars
 

x1 = []
for index, row in dfplot1.iterrows():
    x1.append( (row['students under 3 %']) / (row['high needs %']) )

ind = np.arange(N1)
fig, ax = plt.subplots()

rects1 = ax.bar(ind, x1, width, color='b', alpha=0.4)
rects1[0].set_color('red')

# add some text for labels, title and axes ticks
ax.set_ylabel('Score (% Students lvl 3 or higher / % Students High Need)')
ax.set_xlabel('District')
ax.set_title('District Weighted Scores 2016 (Lower is Better)')
ax.set_xticks(ind + width / len(dfplot1) )
ax.set_xticklabels(dfplot1['district'])

plt.setp(ax.get_xticklabels(), rotation=35, horizontalalignment='right')
        

plt.ylim([.35,1.2])


plt.savefig('student_3orabove_div_highneeds_2016.png', dpi=600, bbox_inches='tight')


plt.show()

# %%
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt


dfplot1 = df2012district.sort_values(['high needs %'] , ascending=False)

N1 = len(dfplot1)

width = 0.35       # the width of the bars
 

x1 = []
for index, row in dfplot.iterrows():
    x1.append( (row['level 3 2012'] + row['level 4 2012'] + row['level 5 2012']) )

x2 = []
for index, row in dfplot.iterrows():
    x2.append( (row['level 3 2016'] + row['level 4 2016'] + row['level 5 2016']) )

ind = np.arange(N)
fig, ax = plt.subplots()

rects1 = ax.bar(ind, x1, width, color='r', alpha=0.4)

rects2 = ax.bar(ind + width, x2, width, color='b', alpha=0.4)

# add some text for labels, title and axes ticks
ax.set_ylabel('number of schools level 3 or higher')
ax.set_xlabel('district')
ax.set_title('Net Number of Schools Level 3 or Higher 2012 vs. 2016')
ax.set_xticks(ind + width / len(dfplot) )
ax.set_xticklabels(dfplot['district'])

ax.legend((rects1[0], rects2[0]), ('2012', '2016'))

plt.setp(ax.get_xticklabels(), rotation=35, horizontalalignment='right')
        

plt.ylim([0,60])


plt.savefig('schools_level_3or_higher_2012vs2016.png', dpi=600, bbox_inches='tight')


plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-287-0cfedaadb238> in <module>()
#      11
#      12 x1 = []
# ---> 13 for index, row in dfplot.iterrows():
#      14     x1.append( (row['level 3 2012'] + row['level 4 2012'] + row['level 5 2012']) )
#      15
#
# NameError: name 'dfplot' is not defined

# %%
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt

dfplot = dfleveldelta.sort_values(['school count'] , ascending=False)

N = len(dfplot)

width = 0.35       # the width of the bars


x1 = []
for index, row in dfplot.iterrows():
    x1.append( (row['level 3 2012'] + row['level 4 2012'] + row['level 5 2012']) / row['school count'] )

x2 = []
for index, row in dfplot.iterrows():
    x2.append( (row['level 3 2016'] + row['level 4 2016'] + row['level 5 2016']) / row['school count'] )

ind = np.arange(N)
fig, ax = plt.subplots()

rects1 = ax.bar(ind, x1, width, color='blue', alpha=0.3)
rects1[6].set_color('red')

rects2 = ax.bar(ind + width, x2, width, color='lightgreen', alpha=0.4)
rects2[6].set_color('cyan')

# add some text for labels, title and axes ticks
ax.set_ylabel('percentage of level 3 or higher')
ax.set_xlabel('district')
ax.set_title('Percentage of Schools Level 3 or Higher out of Total Schools 2012 vs. 2016')
ax.set_xticks(ind + width -1 / len(dfplot) )
ax.set_xticklabels(dfplot['district'])

ax.legend((rects1[0], rects2[0]), ('2012', '2016'))

plt.setp(ax.get_xticklabels(), rotation=35, horizontalalignment='right')
        

plt.ylim([0,1])


#plt.savefig('percentage_schools_level_3or_higher_out_of_total_2012vs2016.png', dpi=600, bbox_inches='tight')


plt.show()

# %%
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt

dfplot = dfleveldelta.sort_values(['school count'], ascending=False)

N = len(dfplot)

width = 0.35       # the width of the bars


x1 = []
for index, row in dfplot.iterrows():
    x1.append( (row['level 3 2012'])  )

x2 = []
for index, row in dfplot.iterrows():
    x2.append( (row['level 3 2016'])  )

ind = np.arange(N)
fig, ax = plt.subplots()

rects1 = ax.bar(ind, x1, width, color='blue', alpha=0.3)
rects1[6].set_color('red')

rects2 = ax.bar(ind + width, x2, width, color='lightgreen', alpha=0.4)
rects2[6].set_color('cyan')

# add some text for labels, title and axes ticks
ax.set_ylabel('number of level 3 schools')
ax.set_xlabel('district')
ax.set_title('number of level 3 schools 2012 vs. 2016')
ax.set_xticks(ind + width / len(dfplot) )
ax.set_xticklabels(dfplot['district'])

ax.legend((rects1[0], rects2[0]), ('2012', '2016'))

plt.setp(ax.get_xticklabels(), rotation=35, horizontalalignment='right')
        

plt.ylim([0,50])


#plt.savefig('schools_level_3_2012vs2016.png', dpi=600, bbox_inches='tight')


plt.show()

# %%
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt

dfplot = dfleveldelta.sort_values(['school count'], ascending=False)

N = len(dfplot)

width = 0.35       # the width of the bars


x1 = []
for index, row in dfplot.iterrows():
    x1.append( (row['level 4 2012']) + (row['level 5 2012'])  )

x2 = []
for index, row in dfplot.iterrows():
    x2.append( (row['level 4 2016']) + (row['level 5 2016'])  )

ind = np.arange(N)
fig, ax = plt.subplots()

rects1 = ax.bar(ind, x1, width, color='blue', alpha=0.3)
rects1[6].set_color('red')

rects2 = ax.bar(ind + width, x2, width, color='lightgreen', alpha=0.4)
rects2[6].set_color('cyan')

# add some text for labels, title and axes ticks
ax.set_ylabel('number of level 4 and 5 schools')
ax.set_xlabel('district')
ax.set_title('Number of Level 4 and 5 Schools 2012 vs. 2016')
ax.set_xticks(ind + width / len(dfplot) )
ax.set_xticklabels(dfplot['district'])

ax.legend((rects1[0], rects2[0]), ('2012', '2016'))

plt.setp(ax.get_xticklabels(), rotation=35, horizontalalignment='right')
        

plt.ylim([0,13])


plt.savefig('schools_level_4-5_2012vs2016.png', dpi=600, bbox_inches='tight')


plt.show()

# %%
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt

dfplot = dfleveldelta.sort_values(['school count'], ascending=False)

N = len(dfplot)

x = []
for index, row in dfplot.iterrows():
    #x.append(  (( row['level 3 2012'] + row['level 4 2012'] + row['level 5 2012']) -  (row['level 3 2016'] + row['level 4 2016'] + row['level 5 2016'])) / row['school count'] )
    x.append(  1 - ((row['level 3 2016'] + row['level 4 2016'] + row['level 5 2016']) /  ( row['level 3 2012'] + row['level 4 2012'] + row['level 5 2012']) ))
    

width = 0.95       # the width of the bars

ind = np.arange(N)
fig, ax = plt.subplots()

rects1 = ax.bar(ind, x, width, color='blue', alpha=0.3)
rects1[6].set_color('red')


# add some text for labels, title and axes ticks
ax.set_ylabel('Percentage of Schools')
ax.set_xlabel('district')
ax.set_title('Percentage of Schools that were level 3 or higher in 2012 and are level 2 or lower in 2016')
ax.set_xticks(ind + width / len(dfplot) )
ax.set_xticklabels(dfplot['district'])
plt.setp(ax.get_xticklabels(), rotation=35, horizontalalignment='right')

plt.ylim([0,.55])


plt.savefig('percent_schools_rose_from_lvl3_barchart.png', dpi=600, bbox_inches='tight')
plt.show()

# %%
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt


x = dfplot['number of schools at level 3 or higher 2012']
y = dfplot['number of schools at level 3 or higher 2016']

colors = np.random.rand(20)

plt.scatter(x, y, s=(dfplot['% schools higher than 3'].apply(lambda x: x * 1000)), c='maroon', alpha=0.5)

plt.show()
